# %%
# !pip install gymnasium
# !pip install stable-baselines3[extra]
# !pip install gym[classic_control]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium in c:\users\raeda\appdata\roaming\python\python311\site-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gymnasium) (1.24.3)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gymnasium) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gymnasium) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gymnasium) (0.0.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in c:\users\raeda\appdata\roaming\python\python311\site-packages (2.0.0)
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (0.28.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (1.24.3)
# Requirement already satisfied: torch>=1.11 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (3.7.2)
# Requirement already satisfied: opencv-python in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: psutil in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (4.65.0)
# Requirement already satisfied: rich in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (13.5.2)
# Requirement already satisfied: shimmy[atari]~=0.2.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (0.2.1)
# Requirement already satisfied: pillow in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (10.0.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: pygame in c:\users\raeda\appdata\roaming\python\python311\site-packages (from stable-baselines3[extra]) (2.5.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: click in c:\users\raeda\appdata\roaming\python\python311\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.1.6)
# Requirement already satisfied: requests in c:\users\raeda\appdata\roaming\python\python311\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.30.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\raeda\appdata\roaming\python\python311\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from shimmy[atari]~=0.2.1->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.56.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.23.4)
# Requirement already satisfied: setuptools>=41.0.0 in c:\program files\python311\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.5.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.41.0)
# Requirement already satisfied: filelock in c:\users\raeda\appdata\roaming\python\python311\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.12.2)
# Requirement already satisfied: sympy in c:\users\raeda\appdata\roaming\python\python311\site-packages (from torch>=1.11->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: networkx in c:\users\raeda\appdata\roaming\python\python311\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\raeda\appdata\roaming\python\python311\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: importlib-resources in c:\users\raeda\appdata\roaming\python\python311\site-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra]) (6.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym[classic_control] in c:\users\raeda\appdata\roaming\python\python311\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gym[classic_control]) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gym[classic_control]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\raeda\appdata\roaming\python\python311\site-packages (from gym[classic_control]) (0.0.8)
# Collecting pygame==2.1.0 (from gym[classic_control])
#   Downloading pygame-2.1.0.tar.gz (5.8 MB)
#      ---------------------------------------- 0.0/5.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.8 MB 1.4 MB/s eta 0:00:05
#       --------------------------------------- 0.1/5.8 MB 1.2 MB/s eta 0:00:05
#       --------------------------------------- 0.1/5.8 MB 1.0 MB/s eta 0:00:06
#      - -------------------------------------- 0.2/5.8 MB 1.1 MB/s eta 0:00:06
#      - -------------------------------------- 0.2/5.8 MB 1.1 MB/s eta 0:00:05
#      - -------------------------------------- 0.3/5.8 MB 1.1 MB/s eta 0:00:05
#      -- ------------------------------------- 0.3/5.8 MB 1.1 MB/s eta 0:00:05
#      -- ------------------------------------- 0.4/5.8 MB 1.1 MB/s eta 0:00:05
#      --- ------------------------------------ 0.4/5.8 MB 1.1 MB/s eta 0:00:05
#      --- ------------------------------------ 0.5/5.8 MB 1.1 MB/s eta 0:00:05
#      --- ------------------------------------ 0.5/5.8 MB 1.1 MB/s eta 0:00:05
#      ---- ----------------------------------- 0.6/5.8 MB 1.1 MB/s eta 0:00:05
#      ---- ----------------------------------- 0.6/5.8 MB 1.1 MB/s eta 0:00:05
#      ---- ----------------------------------- 0.7/5.8 MB 1.1 MB/s eta 0:00:05
#      ----- ---------------------------------- 0.7/5.8 MB 1.1 MB/s eta 0:00:05
#      ----- ---------------------------------- 0.8/5.8 MB 1.1 MB/s eta 0:00:05
#      ----- ---------------------------------- 0.8/5.8 MB 1.1 MB/s eta 0:00:05
#      ------ --------------------------------- 0.9/5.8 MB 1.1 MB/s eta 0:00:05
#      ------ --------------------------------- 0.9/5.8 MB 1.1 MB/s eta 0:00:05
#      ------ --------------------------------- 1.0/5.8 MB 1.1 MB/s eta 0:00:05
#      ------- -------------------------------- 1.0/5.8 MB 1.1 MB/s eta 0:00:05
#      ------- -------------------------------- 1.1/5.8 MB 1.1 MB/s eta 0:00:05
#      ------- -------------------------------- 1.1/5.8 MB 1.1 MB/s eta 0:00:05
#      -------- ------------------------------- 1.2/5.8 MB 1.1 MB/s eta 0:00:05
#      -------- ------------------------------- 1.2/5.8 MB 1.1 MB/s eta 0:00:05
#      -------- ------------------------------- 1.3/5.8 MB 1.1 MB/s eta 0:00:05
#      --------- ------------------------------ 1.3/5.8 MB 1.1 MB/s eta 0:00:05
#      --------- ------------------------------ 1.4/5.8 MB 1.1 MB/s eta 0:00:05
#      --------- ------------------------------ 1.4/5.8 MB 1.1 MB/s eta 0:00:04
#      ---------- ----------------------------- 1.5/5.8 MB 1.1 MB/s eta 0:00:04
#      ---------- ----------------------------- 1.5/5.8 MB 1.1 MB/s eta 0:00:04
#      ---------- ----------------------------- 1.6/5.8 MB 1.1 MB/s eta 0:00:04
#      ----------- ---------------------------- 1.6/5.8 MB 1.1 MB/s eta 0:00:04
#      ----------- ---------------------------- 1.7/5.8 MB 1.1 MB/s eta 0:00:04
#      ------------ --------------------------- 1.8/5.8 MB 1.1 MB/s eta 0:00:04
#      ------------ --------------------------- 1.8/5.8 MB 1.1 MB/s eta 0:00:04
#      ------------ --------------------------- 1.9/5.8 MB 1.1 MB/s eta 0:00:04
#      ------------- -------------------------- 1.9/5.8 MB 1.1 MB/s eta 0:00:04
#      ------------- -------------------------- 2.0/5.8 MB 1.1 MB/s eta 0:00:04
#      ------------- -------------------------- 2.0/5.8 MB 1.1 MB/s eta 0:00:04
#      -------------- ------------------------- 2.1/5.8 MB 1.1 MB/s eta 0:00:04
#      -------------- ------------------------- 2.1/5.8 MB 1.1 MB/s eta 0:00:04
#      -------------- ------------------------- 2.1/5.8 MB 1.1 MB/s eta 0:00:04
#      --------------- ------------------------ 2.2/5.8 MB 1.1 MB/s eta 0:00:04
#      --------------- ------------------------ 2.2/5.8 MB 1.1 MB/s eta 0:00:04
#      --------------- ------------------------ 2.3/5.8 MB 1.1 MB/s eta 0:00:04
#      ---------------- ----------------------- 2.3/5.8 MB 1.1 MB/s eta 0:00:04
#      ---------------- ----------------------- 2.4/5.8 MB 1.1 MB/s eta 0:00:04
#      ---------------- ----------------------- 2.4/5.8 MB 1.1 MB/s eta 0:00:04
#      ----------------- ---------------------- 2.5/5.8 MB 1.1 MB/s eta 0:00:04
#      ----------------- ---------------------- 2.5/5.8 MB 1.1 MB/s eta 0:00:04
#      ----------------- ---------------------- 2.6/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------ --------------------- 2.6/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------ --------------------- 2.7/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------- -------------------- 2.8/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------- -------------------- 2.8/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------- -------------------- 2.8/5.8 MB 1.1 MB/s eta 0:00:03
#      -------------------- ------------------- 2.9/5.8 MB 1.1 MB/s eta 0:00:03
#      -------------------- ------------------- 2.9/5.8 MB 1.1 MB/s eta 0:00:03
#      -------------------- ------------------- 3.0/5.8 MB 1.1 MB/s eta 0:00:03
#      --------------------- ------------------ 3.0/5.8 MB 1.1 MB/s eta 0:00:03
#      --------------------- ------------------ 3.1/5.8 MB 1.1 MB/s eta 0:00:03
#      --------------------- ------------------ 3.1/5.8 MB 1.1 MB/s eta 0:00:03
#      ---------------------- ----------------- 3.2/5.8 MB 1.1 MB/s eta 0:00:03
#      ---------------------- ----------------- 3.3/5.8 MB 1.1 MB/s eta 0:00:03
#      ---------------------- ----------------- 3.3/5.8 MB 1.1 MB/s eta 0:00:03
#      ----------------------- ---------------- 3.4/5.8 MB 1.1 MB/s eta 0:00:03
#      ----------------------- ---------------- 3.4/5.8 MB 1.1 MB/s eta 0:00:03
#      ----------------------- ---------------- 3.5/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------------ --------------- 3.5/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------------ --------------- 3.6/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------------ --------------- 3.6/5.8 MB 1.1 MB/s eta 0:00:03
#      ------------------------- -------------- 3.7/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 3.7/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 3.7/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 3.7/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------- -------------- 3.7/5.8 MB 1.1 MB/s eta 0:00:02
#      -------------------------- ------------- 3.8/5.8 MB 1.1 MB/s eta 0:00:02
#      -------------------------- ------------- 3.8/5.8 MB 1.0 MB/s eta 0:00:02
#      -------------------------- ------------- 3.9/5.8 MB 1.0 MB/s eta 0:00:02
#      --------------------------- ------------ 3.9/5.8 MB 1.0 MB/s eta 0:00:02
#      --------------------------- ------------ 4.0/5.8 MB 1.0 MB/s eta 0:00:02
#      --------------------------- ------------ 4.0/5.8 MB 1.0 MB/s eta 0:00:02
#      ---------------------------- ----------- 4.1/5.8 MB 1.0 MB/s eta 0:00:02
#      ---------------------------- ----------- 4.1/5.8 MB 1.1 MB/s eta 0:00:02
#      ---------------------------- ----------- 4.2/5.8 MB 1.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 4.2/5.8 MB 1.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 4.3/5.8 MB 1.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 4.3/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------ --------- 4.4/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------ --------- 4.4/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------ --------- 4.5/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------- -------- 4.5/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------- -------- 4.6/5.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------- -------- 4.6/5.8 MB 1.1 MB/s eta 0:00:02
#      -------------------------------- ------- 4.7/5.8 MB 1.1 MB/s eta 0:00:02
#      -------------------------------- ------- 4.7/5.8 MB 1.1 MB/s eta 0:00:02
#      --------------------------------- ------ 4.8/5.8 MB 1.1 MB/s eta 0:00:01
#      --------------------------------- ------ 4.8/5.8 MB 1.1 MB/s eta 0:00:01
#      --------------------------------- ------ 4.9/5.8 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 4.9/5.8 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 5.0/5.8 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 5.0/5.8 MB 1.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 5.1/5.8 MB 1.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 5.1/5.8 MB 1.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 5.2/5.8 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------ --- 5.2/5.8 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------ --- 5.3/5.8 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------ --- 5.3/5.8 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------- -- 5.4/5.8 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------- -- 5.4/5.8 MB 1.1 MB/s eta 0:00:01
#      ------------------------------------- -- 5.5/5.8 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 5.5/5.8 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 5.6/5.8 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 5.6/5.8 MB 1.1 MB/s eta 0:00:01
#      -------------------------------------- - 5.6/5.8 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.8 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.8 MB 1.0 MB/s eta 0:00:01
#      ---------------------------------------  5.8/5.8 MB 1.0 MB/s eta 0:00:01
#      ---------------------------------------- 5.8/5.8 MB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [77 lines of output]
#
#
#       WARNING, No "Setup" File Exists, Running "buildconfig/config.py"
#       Using WINDOWS configuration...
#
#       Making dir :prebuilt_downloads:
#       Downloading... https://www.libsdl.org/release/SDL2-devel-2.0.16-VC.zip 13d952c333f3c2ebe9b7bc0075b4ad2f784e7584
#       Unzipping :prebuilt_downloads\SDL2-devel-2.0.16-VC.zip:
#       Downloading... https://www.libsdl.org/projects/SDL_image/release/SDL2_image-devel-2.0.5-VC.zip 137f86474691f4e12e76e07d58d5920c8d844d5b
#       Unzipping :prebuilt_downloads\SDL2_image-devel-2.0.5-VC.zip:
#       Downloading... https://www.libsdl.org/projects/SDL_ttf/release/SDL2_ttf-devel-2.0.15-VC.zip 1436df41ebc47ac36e02ec9bda5699e80ff9bd27
#       Unzipping :prebuilt_downloads\SDL2_ttf-devel-2.0.15-VC.zip:
#       Downloading... https://www.libsdl.org/projects/SDL_mixer/release/SDL2_mixer-devel-2.0.4-VC.zip 9097148f4529cf19f805ccd007618dec280f0ecc
#       Unzipping :prebuilt_downloads\SDL2_mixer-devel-2.0.4-VC.zip:
#       Downloading... https://www.pygame.org/ftp/jpegsr9d.zip ed10aa2b5a0fcfe74f8a6f7611aeb346b06a1f99
#       Unzipping :prebuilt_downloads\jpegsr9d.zip:
#       Downloading... https://pygame.org/ftp/prebuilt-x64-pygame-1.9.2-20150922.zip 3a5af3427b3aa13a0aaf5c4cb08daaed341613ed
#       Unzipping :prebuilt_downloads\prebuilt-x64-pygame-1.9.2-20150922.zip:
#       copying into .\prebuilt-x64
#       Path for SDL: prebuilt-x64\SDL2-2.0.16
#       ...Library directory for SDL: prebuilt-x64/SDL2-2.0.16/lib/x64
#       ...Include directory for SDL: prebuilt-x64/SDL2-2.0.16/include
#       Path for FONT: prebuilt-x64\SDL2_ttf-2.0.15
#       ...Library directory for FONT: prebuilt-x64/SDL2_ttf-2.0.15/lib/x64
#       ...Include directory for FONT: prebuilt-x64/SDL2_ttf-2.0.15/include
#       Path for IMAGE: prebuilt-x64\SDL2_image-2.0.5
#       ...Library directory for IMAGE: prebuilt-x64/SDL2_image-2.0.5/lib/x64
#       ...Include directory for IMAGE: prebuilt-x64/SDL2_image-2.0.5/include
#       Path for MIXER: prebuilt-x64\SDL2_mixer-2.0.4
#       ...Library directory for MIXER: prebuilt-x64/SDL2_mixer-2.0.4/lib/x64
#       ...Include directory for MIXER: prebuilt-x64/SDL2_mixer-2.0.4/include
#       Path for PORTMIDI: prebuilt-x64
#       ...Library directory for PORTMIDI: prebuilt-x64/lib
#       ...Include directory for PORTMIDI: prebuilt-x64/include
#       DLL for SDL2: prebuilt-x64/SDL2-2.0.16/lib/x64/SDL2.dll
#       DLL for SDL2_ttf: prebuilt-x64/SDL2_ttf-2.0.15/lib/x64/SDL2_ttf.dll
#       DLL for SDL2_image: prebuilt-x64/SDL2_image-2.0.5/lib/x64/SDL2_image.dll
#       DLL for SDL2_mixer: prebuilt-x64/SDL2_mixer-2.0.4/lib/x64/SDL2_mixer.dll
#       DLL for portmidi: prebuilt-x64/lib/portmidi.dll
#       Path for FREETYPE not found.
#       ...Found include dir but no library dir in prebuilt-x64.
#       Path for PNG not found.
#       ...Found include dir but no library dir in prebuilt-x64.
#       Path for JPEG not found.
#       ...Found include dir but no library dir in prebuilt-x64.
#       DLL for freetype: prebuilt-x64/SDL2_ttf-2.0.15/lib/x64/libfreetype-6.dll
#
#       ---
#       For help with compilation see:
#           https://www.pygame.org/wiki/CompileWindows
#       To contribute to pygame development see:
#           https://www.pygame.org/contribute.html
#       ---
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\raeda\AppData\Local\Temp\pip-install-l2qp8bpn\pygame_bce4e658ea494188b55d263349efc7bc\setup.py", line 388, in <module>
#           buildconfig.config.main(AUTO_CONFIG)
#         File "C:\Users\raeda\AppData\Local\Temp\pip-install-l2qp8bpn\pygame_bce4e658ea494188b55d263349efc7bc\buildconfig\config.py", line 234, in main
#           deps = CFG.main(**kwds)
#                  ^^^^^^^^^^^^^^^^
#         File "C:\Users\raeda\AppData\Local\Temp\pip-install-l2qp8bpn\pygame_bce4e658ea494188b55d263349efc7bc\buildconfig\config_win.py", line 511, in main
#           return setup_prebuilt_sdl2(prebuilt_dir)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\raeda\AppData\Local\Temp\pip-install-l2qp8bpn\pygame_bce4e658ea494188b55d263349efc7bc\buildconfig\config_win.py", line 471, in setup_prebuilt_sdl2
#           DEPS.configure()
#         File "C:\Users\raeda\AppData\Local\Temp\pip-install-l2qp8bpn\pygame_bce4e658ea494188b55d263349efc7bc\buildconfig\config_win.py", line 336, in configure
#           from . import vstools
#         File "C:\Users\raeda\AppData\Local\Temp\pip-install-l2qp8bpn\pygame_bce4e658ea494188b55d263349efc7bc\buildconfig\vstools.py", line 11, in <module>
#           compiler.initialize()
#         File "C:\Program Files\Python311\Lib\site-packages\setuptools\_distutils\msvc9compiler.py", line 403, in initialize
#           vc_env = query_vcvarsall(VERSION, plat_spec)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Program Files\Python311\Lib\site-packages\setuptools\_distutils\msvc9compiler.py", line 281, in query_vcvarsall
#           raise DistutilsPlatformError("Unable to find vcvarsall.bat")
#       distutils.errors.DistutilsPlatformError: Unable to find vcvarsall.bat
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import os


models_dir = "models/PPO"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

# %%
import gymnasium as gym
from stable_baselines3 import PPO
import os


models_dir = "raed8"



model = PPO('MlpPolicy', 'Pendulum-v1', verbose=1, tensorboard_log=models_dir)

TIMESTEPS = 500_000
iters = 0
model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False,tb_log_name='PPO_baseline1')
# Out:
# Using cuda device
# Creating environment from the given name 'Pendulum-v1'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to raed8\PPO_baseline1_0
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.22e+03 |
# | time/              |           |
# |    fps             | 403       |
# |    iterations      | 1         |
# |    time_elapsed    | 5         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 307          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0019854342 |
# |    clip_fraction        | 0.00479      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00446     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5e+03      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000502    |
# |    std                  | 0.999        |
# |    value_loss           | 9.42e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.24e+03   |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.002376689 |
# |    clip_fraction        | 0.00327     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.44e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000621   |
# |    std                  | 0.995       |
# |    value_loss           | 8.97e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 326         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.001977385 |
# |    clip_fraction        | 0.00454     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.0841      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.76e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000897   |
# |    std                  | 0.992       |
# |    value_loss           | 9.35e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.2e+03     |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 5            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0035180626 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.0665       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.63e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 0.975        |
# |    value_loss           | 7.98e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.2e+03     |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 6            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0037587069 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00887      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.16e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00151     |
# |    std                  | 0.973        |
# |    value_loss           | 6.64e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 345          |
# |    iterations           | 7            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0033490534 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.00261      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.17e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00363     |
# |    std                  | 0.987        |
# |    value_loss           | 7.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 8            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0016877891 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.00182      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.75e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000658    |
# |    std                  | 0.989        |
# |    value_loss           | 7.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 356          |
# |    iterations           | 9            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0023574024 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.001        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.14e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00173     |
# |    std                  | 0.992        |
# |    value_loss           | 1.03e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 359          |
# |    iterations           | 10           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0013412852 |
# |    clip_fraction        | 0.00254      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00168      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00067     |
# |    std                  | 1.01         |
# |    value_loss           | 5.99e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.2e+03    |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 11          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004640469 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.000974    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.48e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00225    |
# |    std                  | 0.985       |
# |    value_loss           | 7.66e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 364          |
# |    iterations           | 12           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0049743215 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.000769     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.57e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00303     |
# |    std                  | 0.983        |
# |    value_loss           | 5.34e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.18e+03    |
# | time/                   |              |
# |    fps                  | 366          |
# |    iterations           | 13           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0042288434 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000415     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.55e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00172     |
# |    std                  | 0.972        |
# |    value_loss           | 5.81e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.17e+03   |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 14          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004477849 |
# |    clip_fraction        | 0.02        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.000271    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.97e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00359    |
# |    std                  | 0.979       |
# |    value_loss           | 7.08e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 370          |
# |    iterations           | 15           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0026923686 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000243     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00194     |
# |    std                  | 0.951        |
# |    value_loss           | 5.73e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.18e+03   |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 16          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002441217 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.000166    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.27e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00196    |
# |    std                  | 0.954       |
# |    value_loss           | 6.36e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.17e+03    |
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 17           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0020821556 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000166     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.45e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00176     |
# |    std                  | 0.971        |
# |    value_loss           | 5.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 18           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0023373659 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.000129     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.93e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00207     |
# |    std                  | 0.985        |
# |    value_loss           | 5.89e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 19           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0041967034 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.000104     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.75e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00258     |
# |    std                  | 0.975        |
# |    value_loss           | 5.51e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 20           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0030992832 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.000109     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.22e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 0.99         |
# |    value_loss           | 5.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 21           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0032069585 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 8.65e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00249     |
# |    std                  | 0.979        |
# |    value_loss           | 4.22e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 377          |
# |    iterations           | 22           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0034940531 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 8.17e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.02e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00314     |
# |    std                  | 0.952        |
# |    value_loss           | 4.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 378          |
# |    iterations           | 23           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0016530653 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 4.16e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 0.947        |
# |    value_loss           | 5.46e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 24           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0014846707 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 4.86e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000859    |
# |    std                  | 0.944        |
# |    value_loss           | 3.35e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.13e+03   |
# | time/                   |             |
# |    fps                  | 379         |
# |    iterations           | 25          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003756164 |
# |    clip_fraction        | 0.0237      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 2.69e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.91e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00274    |
# |    std                  | 0.939       |
# |    value_loss           | 6.68e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 26           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0028930516 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 4.07e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00145     |
# |    std                  | 0.947        |
# |    value_loss           | 3.86e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 27           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0025216138 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 2e-05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.59e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00193     |
# |    std                  | 0.937        |
# |    value_loss           | 5.82e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 28           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0055851964 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 3.12e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00242     |
# |    std                  | 0.941        |
# |    value_loss           | 2.81e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.13e+03   |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 29          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004234193 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 2.06e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00228    |
# |    std                  | 0.939       |
# |    value_loss           | 3.86e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 30           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0044907527 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 1.62e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00258     |
# |    std                  | 0.939        |
# |    value_loss           | 4e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 31           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0020299153 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 1.5e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.16e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00121     |
# |    std                  | 0.948        |
# |    value_loss           | 3.84e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 32           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0057713436 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 1.25e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00384     |
# |    std                  | 0.962        |
# |    value_loss           | 4.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 33           |
# |    time_elapsed         | 176          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0039311564 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 1.34e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 996          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.951        |
# |    value_loss           | 2.4e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.15e+03   |
# | time/                   |             |
# |    fps                  | 383         |
# |    iterations           | 34          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.002631614 |
# |    clip_fraction        | 0.00762     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 8.29e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2e+03       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00248    |
# |    std                  | 0.928       |
# |    value_loss           | 4.64e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 35           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0018517394 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 6.62e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000647    |
# |    std                  | 0.918        |
# |    value_loss           | 3.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 36           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0039026467 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 1.03e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.932        |
# |    value_loss           | 2.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 37           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0020563828 |
# |    clip_fraction        | 0.00649      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 7.93e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.906        |
# |    value_loss           | 2.84e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 38           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0033522258 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 5.72e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000686    |
# |    std                  | 0.903        |
# |    value_loss           | 3.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 39           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0056881416 |
# |    clip_fraction        | 0.06         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 4.89e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00538     |
# |    std                  | 0.908        |
# |    value_loss           | 2.27e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 40           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0046979934 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 8.46e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 839          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00169     |
# |    std                  | 0.905        |
# |    value_loss           | 2.1e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.12e+03   |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 41          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.003705086 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 4.71e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 0.913       |
# |    value_loss           | 2.96e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.12e+03   |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 42          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004924151 |
# |    clip_fraction        | 0.0247      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 3.46e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00273    |
# |    std                  | 0.89        |
# |    value_loss           | 2.37e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.11e+03    |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 43           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0082675535 |
# |    clip_fraction        | 0.0853       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 3.93e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 880          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00792     |
# |    std                  | 0.888        |
# |    value_loss           | 2.23e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 44           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0047598956 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 3.46e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 872          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.888        |
# |    value_loss           | 2.29e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.09e+03    |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 45           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0052708676 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 3.34e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 715          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00246     |
# |    std                  | 0.858        |
# |    value_loss           | 1.85e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 46           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0048109554 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 2.86e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 871          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00256     |
# |    std                  | 0.842        |
# |    value_loss           | 1.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 47           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0053648157 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 3.7e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 523          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00278     |
# |    std                  | 0.824        |
# |    value_loss           | 1.3e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 48           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0042939475 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 2.98e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 962          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00262     |
# |    std                  | 0.817        |
# |    value_loss           | 2.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.08e+03    |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 49           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0043812133 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 3.7e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 628          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00242     |
# |    std                  | 0.799        |
# |    value_loss           | 1.39e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.06e+03   |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 50          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004374237 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 3.04e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 700         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 0.796       |
# |    value_loss           | 1.22e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.05e+03    |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 51           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0030110625 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 2.8e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 616          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 0.788        |
# |    value_loss           | 1.49e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.04e+03    |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 52           |
# |    time_elapsed         | 275          |
# |    total_timesteps      | 106496       |
# ...
# |    std                  | 0.421       |
# |    value_loss           | 53.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -212        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 143         |
# |    time_elapsed         | 1029        |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.007733582 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.01        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.0014      |
# |    std                  | 0.414       |
# |    value_loss           | 16.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -202        |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 144         |
# |    time_elapsed         | 1040        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.002987896 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.8        |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.002      |
# |    std                  | 0.413       |
# |    value_loss           | 158         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -206       |
# | time/                   |            |
# |    fps                  | 282        |
# |    iterations           | 145        |
# |    time_elapsed         | 1050       |
# |    total_timesteps      | 296960     |
# | train/                  |            |
# |    approx_kl            | 0.01755786 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.516     |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.9        |
# |    n_updates            | 1440       |
# |    policy_gradient_loss | -0.00302   |
# |    std                  | 0.397      |
# |    value_loss           | 6.11       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -194         |
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 146          |
# |    time_elapsed         | 1060         |
# |    total_timesteps      | 299008       |
# | train/                  |              |
# |    approx_kl            | 0.0019127249 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.6         |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.00245     |
# |    std                  | 0.402        |
# |    value_loss           | 45.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -192        |
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 147         |
# |    time_elapsed         | 1070        |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.006211364 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.506      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.655       |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | 0.000944    |
# |    std                  | 0.401       |
# |    value_loss           | 18.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -189        |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 148         |
# |    time_elapsed         | 1080        |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.013709969 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | 0.0111      |
# |    std                  | 0.401       |
# |    value_loss           | 5.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -183        |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 149         |
# |    time_elapsed         | 1091        |
# |    total_timesteps      | 305152      |
# | train/                  |             |
# |    approx_kl            | 0.022397129 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.92        |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | 4.06e-05    |
# |    std                  | 0.404       |
# |    value_loss           | 23.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -180        |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 150         |
# |    time_elapsed         | 1101        |
# |    total_timesteps      | 307200      |
# | train/                  |             |
# |    approx_kl            | 0.010090541 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23        |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.000248   |
# |    std                  | 0.403       |
# |    value_loss           | 6.8         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -173        |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 151         |
# |    time_elapsed         | 1111        |
# |    total_timesteps      | 309248      |
# | train/                  |             |
# |    approx_kl            | 0.018291134 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | 0.00175     |
# |    std                  | 0.403       |
# |    value_loss           | 3.6         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -175        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 152         |
# |    time_elapsed         | 1121        |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.015087677 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21        |
# |    n_updates            | 1510        |
# |    policy_gradient_loss | 0.000365    |
# |    std                  | 0.385       |
# |    value_loss           | 2.64        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -171       |
# | time/                   |            |
# |    fps                  | 159        |
# |    iterations           | 153        |
# |    time_elapsed         | 1969       |
# |    total_timesteps      | 313344     |
# | train/                  |            |
# |    approx_kl            | 0.00940928 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.465     |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.7        |
# |    n_updates            | 1520       |
# |    policy_gradient_loss | 0.00287    |
# |    std                  | 0.386      |
# |    value_loss           | 9.77       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -168        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 154         |
# |    time_elapsed         | 1982        |
# |    total_timesteps      | 315392      |
# | train/                  |             |
# |    approx_kl            | 0.024855914 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 1530        |
# |    policy_gradient_loss | -0.000694   |
# |    std                  | 0.388       |
# |    value_loss           | 8.99        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 200       |
# |    ep_rew_mean          | -161      |
# | time/                   |           |
# |    fps                  | 159       |
# |    iterations           | 155       |
# |    time_elapsed         | 1993      |
# |    total_timesteps      | 317440    |
# | train/                  |           |
# |    approx_kl            | 0.0222519 |
# |    clip_fraction        | 0.175     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.461    |
# |    explained_variance   | 0.994     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.381     |
# |    n_updates            | 1540      |
# |    policy_gradient_loss | 0.00482   |
# |    std                  | 0.38      |
# |    value_loss           | 1.46      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 156         |
# |    time_elapsed         | 2004        |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.020447917 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0997      |
# |    n_updates            | 1550        |
# |    policy_gradient_loss | 0.00268     |
# |    std                  | 0.373       |
# |    value_loss           | 1.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 157         |
# |    time_elapsed         | 2016        |
# |    total_timesteps      | 321536      |
# | train/                  |             |
# |    approx_kl            | 0.006807872 |
# |    clip_fraction        | 0.0962      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.43       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 1560        |
# |    policy_gradient_loss | 0.000661    |
# |    std                  | 0.37        |
# |    value_loss           | 10.2        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#      12 TIMESTEPS = 500_000
#      13 iters = 0
# ---> 14 model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False,tb_log_name='PPO_baseline1')
#
# File c:\Program Files\Python311\Lib\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File c:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:259, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
# --> 259     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     261     if continue_training is False:
#     262         break
#
# File c:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:176, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     174 # Clip the actions to avoid out of bound error
#     175 if isinstance(self.action_space, spaces.Box):
# --> 176     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     178 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     180 self.num_timesteps += env.num_envs
#
# File <__array_function__ internals>:177, in clip(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
model_path = f"{models_dir}/80000.zip"
model = PPO.load(model_path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
from stable_baselines3.common.evaluation import evaluate_policy
env=gym.make('Pendulum-v1',render_mode='human')
evaluate_policy(model, env, n_eval_episodes=10, render=True)
env.close()
# Out:
# c:\Program Files\Python311\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
env.close()
